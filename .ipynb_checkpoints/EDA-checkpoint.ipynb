# %% [markdown]
# # General EDA

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_csv('kc_house_data.csv', index_col='id')

# %%
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7      1180.0
# 6414100192      7242     2.0           0     0          3      7      2170.0
# 5631500400     10000     1.0           0     0          3      6       770.0
# 2487200875      5000     1.0           0     0          5      7      1050.0
# 1954400510      8080     1.0           0     0          3      8      1680.0
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 2487200875           1360        5000
# 1954400510           1800        7503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 7129300520 to 1523300157
# Data columns (total 20 columns):
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21611 non-null float64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(6), int64(13), object(1)
# memory usage: 3.5+ MB

# %%
df.date =df.date.apply(lambda x: x[:4]+'-'+x[4:6]+'-'+x[6:8])
df.date =pd.to_datetime(df.date)

# %%
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.date.value_counts()

### Sales over the year
# Out:
# 2014-06-23    142
# 2014-06-25    131
# 2014-06-26    131
# 2014-07-08    127
# 2015-04-27    126
# 2015-03-25    123
# 2014-07-09    121
# 2015-04-14    121
# 2015-04-22    121
# 2015-04-28    121
# 2014-06-24    120
# 2015-04-21    119
# 2014-10-28    117
# 2014-08-26    117
# 2014-05-20    116
# 2014-07-14    116
# 2014-07-01    115
# 2014-08-20    114
# 2015-04-29    114
# 2014-06-17    113
# 2015-04-08    112
# 2014-07-29    112
# 2014-05-28    111
# 2014-07-16    111
# 2014-08-05    110
# 2015-04-23    110
# 2015-03-27    109
# 2014-08-25    109
# 2014-08-11    107
# 2014-06-20    107
#              ...
# 2015-02-14      3
# 2014-08-10      3
# 2015-03-15      3
# 2014-09-07      2
# 2014-08-24      2
# 2014-08-09      2
# 2014-05-11      2
# 2014-10-11      2
# 2014-12-21      2
# 2015-05-10      2
# 2014-11-28      2
# 2015-02-01      2
# 2014-11-15      2
# 2014-12-27      2
# 2014-07-04      2
# 2014-12-07      2
# 2014-08-30      1
# 2015-01-17      1
# 2014-11-30      1
# 2015-01-31      1
# 2015-05-27      1
# 2015-02-15      1
# 2015-01-10      1
# 2014-08-03      1
# 2014-05-17      1
# 2014-07-27      1
# 2015-03-08      1
# 2014-11-02      1
# 2015-05-15      1
# 2015-05-24      1
# Name: date, Length: 372, dtype: int64

# %%
print(df.date.max())
print(df.date.min())
# Out:
# 2015-05-27 00:00:00
# 2014-05-02 00:00:00

# %% [markdown]
# ## Look at Distributions

# %%
price_predictors = df.iloc[:,2:]

# %%
price_predictors.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20,30))
# fig.suptitle('Graphs of Feature Distributions')
# n =1 #used for iteration below, DONT NEED IF USING np.ravel

# for row in range(3):
#     for col in range(4):
# to avoid row col nonsense  use below
list_of_subplots = np.ravel(axes)

for index,col in enumerate(price_predictors.columns):
# ax = axes[row][col]
# y = [n*xi for xi in x]
    list_of_subplots[index].hist(price_predictors[col])
    list_of_subplots[index].set_title('{}'.format(col))
fig.savefig('dist_of_features')    #saves fig in current folder

# %% [markdown]
# ## Look at correlation

# %%
price_predictors = df.iloc[:,2:]
corr = price_predictors.corr()

# %% [markdown]
# ### Function to color corr dataframe

# %%
# color green if above .7 coor and red if above -.7 corr
def color(val):
    if abs(val)<.5:
        color = 'black'
        return 'color: %s' % color
    elif val:
        color ='green'
        return 'color: %s' % color 
    else:
        color ='red'
        return 'color: %s' % color

# %%
s = corr.style.applymap(color)
s
# Out:
# <style  type="text/css" >
#     #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col0 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col1 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col2 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col3 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col4 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col5 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col6 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col7 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col8 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col9 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col10 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col11 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col12 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col13 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col14 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col15 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col16 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row0_col17 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col0 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col1 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col2 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col3 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col4 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col5 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col6 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col7 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col8 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col9 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col10 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col11 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col12 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col13 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col14 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col15 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col16 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row1_col17 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col0 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col1 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col2 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col3 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col4 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col5 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col6 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col7 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col8 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col9 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col10 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col11 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col12 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col13 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col14 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col15 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col16 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row2_col17 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col0 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col1 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col2 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col3 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col4 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col5 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col6 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col7 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col8 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col9 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col10 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col11 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col12 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col13 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col14 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col15 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col16 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row3_col17 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col0 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col1 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col2 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col3 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col4 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col5 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col6 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col7 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col8 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col9 {
#             color:  green;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col10 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col11 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col12 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col13 {
#             color:  black;
#         }    #T_0faf75da_52ad_11ea_bb41_acde48001122row4_col14 {
#             color:  black;
#         }    #T_0faf75da_52ad

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr)

# %% [markdown]
# ## Run prliminary OLS

# %%
ols_formula ='price~'+'+'.join(price_predictors.columns)

# %%
simple_reg = ols(formula=ols_formula,data=df).fit()
simple_reg.summary()

# simple_reg = ols(formula="mpg~horsepower",data=auto).fit()
# simple_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2960.
# Date:                Tue, 18 Feb 2020   Prob (F-statistic):               0.00
# Time:                        17:06:33   Log-Likelihood:            -2.9458e+05
# No. Observations:               21611   AIC:                         5.892e+05
# Df Residuals:                   21593   BIC:                         5.893e+05
# Df Model:                          17
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       6.73e+06   2.93e+06      2.296      0.022    9.84e+05    1.25e+07
# bedrooms      -3.579e+04   1892.146    -18.914      0.000   -3.95e+04   -3.21e+04
# bathrooms      4.113e+04   3253.895     12.639      0.000    3.47e+04    4.75e+04
# sqft_living     110.4991      2.270     48.671      0.000     106.049     114.949
# sqft_lot          0.1285      0.048      2.682      0.007       0.035       0.222
# floors         6697.3438   3596.011      1.862      0.063    -351.104    1.37e+04
# waterfront      5.83e+05   1.74e+04     33.580      0.000    5.49e+05    6.17e+05
# view           5.286e+04   2140.144     24.698      0.000    4.87e+04    5.71e+04
# condition      2.636e+04   2351.623     11.211      0.000    2.18e+04     3.1e+04
# grade          9.589e+04   2152.847     44.539      0.000    9.17e+04       1e+05
# sqft_above       70.7739      2.254     31.404      0.000      66.357      75.191
# sqft_basement    39.7171      2.647     15.004      0.000      34.528      44.906
# yr_built      -2620.6943     72.664    -36.066      0.000   -2763.121   -2478.268
# yr_renovated     19.7942      3.656      5.415      0.000      12.629      26.960
# zipcode        -582.8128     32.989    -17.667      0.000    -647.473    -518.153
# lat            6.028e+05   1.07e+04     56.150      0.000    5.82e+05    6.24e+05
# long          -2.147e+05   1.31e+04    -16.348      0.000    -2.4e+05   -1.89e+05
# sqft_living15    21.6583      3.448      6.282      0.000      14.900      28.416
# sqft_lot15       -0.3828      0.073     -5.224      0.000      -0.526      -0.239
# ==============================================================================
# Omnibus:                    18380.066   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1867115.072
# Skew:                           3.565   Prob(JB):                         0.00
# Kurtosis:                      47.974   Cond. No.                     1.13e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
